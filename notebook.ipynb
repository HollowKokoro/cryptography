# %% [markdown]
# Задание 1.
#
# Напишите функцию конвертации текста, представленном в шестнацеричном виде, в base64.
#
# Пример:
#
# Входные данные:
#
# 49276d207374756479696e672043727970746f677261706879206c696b6520436c6175646520456c776f6f64205368616e6e6f6e21
#
# Выходные данные:
#
# SSdtIHN0dWR5aW5nIENyeXB0b2dyYXBoeSBsaWtlIENsYXVkZSBFbHdvb2QgU2hhbm5vbiE=

# %%
from codecs import decode, encode

# %%
def hex_decode(text):
    return decode(text, 'hex')

# %%
correct_answer = 'SSdtIHN0dWR5aW5nIENyeXB0b2dyYXBoeSBsaWtlIENsYXVkZSBFbHdvb2QgU2hhbm5vbiE='
hex_str = '49276d207374756479696e672043727970746f677261706879206c696b6520436c6175646520456c776f6f64205368616e6e6f6e21'
b64 = encode(hex_decode(hex_str), 'base64').decode().strip()
b64 == correct_answer
# Out:
# True

# %% [markdown]
# Задание 2.
#
# Напишите функцию, которая принимает в качестве параметров два буфера одинаковой длины и производит операцию XOR над ними.
#
# Пример:
#
# Входные данные:
#
# 506561636520416c6c204f7665722054686520576f726c64
#
# XOR
#
# 4949544353551c0111001f010100061a021f010100061a02
#
# =
#
# 192C352036755D6D7D2050776472264E6A7A21566F747666

# %%
def xor(str1, str2):
    return int(str1, 16) ^ int(str2, 16)

# %%
str1 = "506561636520416c6c204f7665722054686520576f726c64"
str2 = "4949544353551c0111001f010100061a021f010100061a02"
res = "192C352036755D6D7D2050776472264E6A7A21566F747666"

xor_result = hex(xor(str1, str2))[2:].upper()
xor_result == res
# Out:
# True

# %% [markdown]
# Задание 3.
#
# (не использовать метод полного перебора ключа)
#
# Дана строка закодированная в 16-виде. Данную строку получили путем операции XOR некоторого текста с одним символом. Расшифруйте это сообщение.
#
# Пример:
#
# Входные данные:
#
# 19367831362e3d2b2c353d362c783136783336372f343d3c3f3d7839342f39212b782839212b782c303d783a3d2b2c7831362c3d2a3d2b2c
#
# Стадии выполнения задания:
#
# 1: выполните задание без программной автоматизации - "на листочке".
# 2: напишите программу дешифратор.

# %%
input = '19367831362e3d2b2c353d362c783136783336372f343d3c3f3d7839342f39212b782839212b782c303d783a3d2b2c7831362c3d2a3d2b2c'

res = {}

for i in range(0, len(input), 2):
    if input[i:i+2] in res.keys():
        res[input[i:i+2]] += 1
    else:
        res[input[i:i+2]] = 1

print(res)
# Out:
# {'19': 1, '36': 6, '78': 8, '31': 3, '2e': 1, '3d': 8, '2b': 5, '2c': 6, '35': 1, '33': 1, '37': 1, '2f': 2, '34': 2, '3c': 1, '3f': 1, '39': 3, '21': 2, '28': 1, '30': 1, '3a': 1, '2a': 1}

# %%
max_value = max(res.values())
keys_all = []
list(map(lambda key, value:
         keys_all.append(key) if value == max_value else (),
         res.keys(),
         res.values()))
print(keys_all)
# Out:
# ['78', '3d']

# %%
char = "e".encode('ascii').hex()
keys = list(map(lambda x: hex(xor(char, x)), keys_all))
print(keys)
# Out:
# ['0x1d', '0x58']

# %%
input = list(map(lambda i: input[i:i+2], range(0, len(input), 2)))
hex = [[chr(xor(key, a)) for a in input] for key in keys]

print(list((map(lambda x: ''.join(x), hex))))
# Out:
# ['\x04+e,+3 61( +1e,+e.+*2) !" e$)2$<6e5$<6e1- e\' 61e,+1 7 61', 'An investment in knowledge always pays the best interest']

# %% [markdown]
# Задание 5.
# Реализуйте шифрование XOR'ом с повторяющимся ключом.
#
#
# Пример:
#
# Входные данные: ссылка
#
# Ключ: Shannon
#
# Результат: 

# %%
input = open("task15.input", "r").readlines()
input = ''.join(input).strip()
input = bytes(input, 'utf-8')
key = b'Shannon'

# %%
encoded = []
list(map(lambda i: encoded.append(input[i] ^ key[i % len(key)]), range(0, len(input))))
print(bytes(encoded).hex())
# Out:
# 
